# %% [markdown]
# # EDA DataSets (Draft)

# %%
import pandas as pd
import openpyxl

# load xlsx, sheet_name = '2022_2023'
players2223 = pd.read_excel('../documents_kickoff_SFC/players_SL_v2_rawdata.xlsx', sheet_name='players_2022_2023')
players2324 = pd.read_excel('../documents_kickoff_SFC/players_SL_v2_rawdata.xlsx', sheet_name='players_2023_2024')

# load csv
pm_2223 = pd.read_csv('../documents_kickoff_SFC/playing_minutes_2022_2023.csv')
pm_2324 = pd.read_csv('../documents_kickoff_SFC/playing_minutes_2023_2024.csv')

# %% [markdown]
# ## players_SL_v2

# %% [markdown]
# ### Season 2022/23

# %%
players2223.sample(20)
# Out:
#                  Player  Minutes Played  Starting  Substitute  Substituted In  \
# 170      Kastriot Imeri            1401        15          14              12
# 189         Liam Millar            1448        15          17               9
# 261         Noah Streit               0         0           1               0
# 196          Luca Zuffi             750         7          25              11
# 67        Daouda Guindo            1304        14           2               1
# 342       Wylan Cyprien            1370        17           2               1
# 337        VÃ­ctor Ruiz             161         2           0               0
# 54   Carmine Chiappetta             146         1          14               5
# 172  Kevin Fickentscher             249         3          29               0
# 308   Shkelqim Demhasaj             633         7          16               6
# 301    Sayfallah Ltaief             788         7          16              14
# ...

# %% [markdown]
# **Insights**:
# - `Club_Number`
#     - Servette FC = 61
#     - BSC Young Boys = 452
#     - FC BAsel 1893 = 26

# %%
# show all rows with value 'Servette FC' in column 'Club'
players[players['Club'] == 'Servette FC']
# Out:
#                    Player  Minutes Played  Starting  Substitute  \
# 14         Alexander Lyng               0         0           8
# 16         Alexis Antunes            1508        18           6
# 25          Anthony Baron             737         8          11
# 47        BendegÃºz Bolla            1046        11          14
# 57        Bradley Mazikou            1918        23           4
# 69            Chris Bedia            1249        14           3
# 83          David Douline             827         9           8
# 87          Dereck Kutesa            2098        24           5
# 101           Dylan Bronn             366         4           3
# 110         Enzo Crivelli            1327        13          11
# 130          GaÃ«l Ondoua            1872        20           8
# 141        Hussayn Touati             146         1          16
# 148           Issa Kaloga               0         0           2
# 155    Jarell NjikÃ© Simo               0         0           1
# ...

# %% [markdown]
# ### Season 2023/2024

# %%
players2324.sample(20)
# Out:
#                     Player  Minutes Played  Starting  Substitute  \
# 327  Richard van der Venne              59         0          10
# 235          Markus Kuster             540         6          25
# 332            Roman Macek            1370        16          14
# 52        Bledian Krasniqi            1388        15          12
# 263     Mihailo Stevanovic            1103        10          20
# 354          Shaho Maroufi              29         0           2
# 366       Takuma Nishimura             417         5           2
# 262          Mihael Klepac             158         1          14
# 186       JÃ©rÃ©my Vachoux            1170        13           9
# 20            Amadou Dante             630         7           1
# 240          Marvin Keller            2250        25           5
# 403            Yusuf Demir             566         6           8
# 326     Riccardo Calafiori             253         3           0
# ...

# %% [markdown]
# ## playing_minutes_2022_2023
